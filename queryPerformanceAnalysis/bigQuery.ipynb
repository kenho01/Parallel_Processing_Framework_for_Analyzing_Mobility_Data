# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/kenho/Documents/GitHub/AY2425_Ken_Process-Optimisation/gho014fyp-bd70903b082d.json"

# %%
from google.cloud import bigquery

client = bigquery.Client()
query = """
SELECT d.DRIVER_ID, AVG(duration_s) AS average_trip_duration, AVG(distance_km) AS average_trip_distance
FROM `mobilitydata.fact_trips` f
LEFT JOIN `mobilitydata.dim_vehicle` v ON f.VEHICLE_ID = v.VEHICLE_ID
LEFT JOIN `mobilitydata.dim_driver` d ON f.DRIVER_ID = d.DRIVER_ID
LEFT JOIN `mobilitydata.dim_pickup_time` pt ON f.DT_START_ID = pt.PICKUP_TIME_ID
LEFT JOIN `mobilitydata.dim_dropoff_time` do ON f.DT_END_ID = do.DROPOFF_TIME_ID
LEFT JOIN `mobilitydata.dim_pickup_location`pu ON f.PICKUP_LOCATION_ID = pu.PICKUP_LOCATION_ID
LEFT JOIN `mobilitydata.dim_dropoff_location` dl ON f.DROPOFF_LOCATION_ID = dl.DROPOFF_LOCATION_ID
GROUP BY d.DRIVER_ID

"""
results = client.query(query)
df = results.to_dataframe()
display(df)
# Out:
# /Users/kenho/Documents/GitHub/AY2425_Ken_Process-Optimisation/venv/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1820: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#                                                               DRIVER_ID  \
# 0      6c5bc5feafac93fd34674885a1c3e2ed68d2d9d89bcad90f0362579d14f6c485
# 1      6e5f77f066594c91b4799e55c48bc66034f305d0a7b1d2de26a3e4e1d630662f
# 2      1b8f6c325844e3fcc04c653f8d88adeda3489c7ed306451815d065ce92f4d89f
# 3      1cbd8f0d29c2ce3dcb27f41f222c081d46c74f70fa977a8b6c9b3c8d56b07198
# 4      1c1ac641674af5abde9da4b571e7143b8bb05f62970d17fe9701e34f356ad633
# ...                                                                 ...
# 65404  f49ad4db28c3a14c0b230c34816121c81d60e888635fff798a467af2517d3bc0
# 65405  d95b5200771388024dae6f146ec7acf62ca7795e71cfd9c75577333ca102b2f2
# 65406  cc2c514e95bafd4dc428a06a9c4ac10fde3f63c5b9d03d73042470d9b85fe2e5
# ...

# %%
import pandas as pd
dl = pd.read_csv('/Users/kenho/Documents/GitHub/AY2425_Ken_Process-Optimisation/results/Feb2022_cleaned.csv', parse_dates=['DT_START'])
display(dl.count)
# Out:
# <bound method DataFrame.count of           Unnamed: 0                                         VEHICLE_ID  \
# 0                  0  0030060e592ad8ebd0ddcd96e3adc864daae3cdc92d7a3...
# 1                  1  0030060e592ad8ebd0ddcd96e3adc864daae3cdc92d7a3...
# 2                  2  0030060e592ad8ebd0ddcd96e3adc864daae3cdc92d7a3...
# 3                  3  0030060e592ad8ebd0ddcd96e3adc864daae3cdc92d7a3...
# 4                  4  0030060e592ad8ebd0ddcd96e3adc864daae3cdc92d7a3...
# ...              ...                                                ...
# 11165020     1484724  ffff1913a73550cd7f8dd5f764d51443475a690f794163...
# 11165021     1484725  ffff1913a73550cd7f8dd5f764d51443475a690f794163...
# 11165022     1484726  ffff1913a73550cd7f8dd5f764d51443475a690f794163...
# 11165023     1484727  ffff1913a73550cd7f8dd5f764d51443475a690f794163...
# 11165024     1484728  ffff1913a73550cd7f8dd5f764d51443475a690f794163...
#
#                                                   DRIVER_ID  \
# ...

# %%
import pandas as pd
from google.cloud import bigquery
pd.set_option('display.max_colwidth', None)
client = bigquery.Client()
query = """
SELECT *
FROM `test.feb2022_trips`
WHERE REQUEST_ID LIKE "b49d3feb0259123268caa7660790cf0fefbc8774a2de62%"
"""
results = client.query(query)
df = results.to_dataframe()
display(df)
# Out:
# /Users/kenho/Documents/GitHub/AY2425_Ken_Process-Optimisation/venv/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1820: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    int64_field_0  \
# 0        1107405
#
#                                                          VEHICLE_ID  \
# 0  c0ff44884412117234d664884d5a77d83def023412b8493716fe415f777d6b4b
#
#                                                           DRIVER_ID  \
# 0  312b6fecd088506ea556e9518d64ba886aa4f22ff88fe42efe638ee3a70f0fea
#
#                                                          REQUEST_ID  \
# 0  b49d3feb0259123268caa7660790cf0fefbc8774a2de62d28715bfe77f54ef97
#
#                    DT_START                    DT_END  LATITUDE_PICKUP  \
# 0 2022-02-01 00:00:00+00:00 2022-02-01 00:28:33+00:00         1.388362
#
#    LONGITUDE_PICKUP  LATITUDE_END  LONGITUDE_END  distance_km  duration_s
# ...
